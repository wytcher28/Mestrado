# %% [markdown]
# <a href="https://colab.research.google.com/github/wytcher28/Mestrado/blob/main/Ambiente_Teste_FL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# python3 "/content/drive/MyDrive/FL_CKKS_PROJETO/snapshots/2025-12-12_1901/run_experimento_fl_ckks.py" \
#   --base-data "/content/drive/MyDrive/Base de Dados" \
#   --outdir "/content/drive/MyDrive/FL_CKKS_PROJETO/outputs" \
#   --only-phase "Oficial – CheXchoNet" \
#   --iters 10 \
#   --clients 5 \
#   --vector-size 4096 \
#   --poly-degree 8192 \
#   --coeff-bits "60,40,40,60" \
#   --scale 40
# Out:
# ...
# Fase experimental: Oficial – CheXchoNet
# Root dataset : /content/drive/MyDrive/Base de Dados/Oficial/extracted/chexchonet-a-chest-radiograph-dataset-with-gold-standard-echocardiography-labels-1.0.0
# Modo         : unlabeled
# Metadata     : NÃO encontrada
# → Métricas supervisionadas DESABILITADAS
#   (somente latência, custo, overhead, escalabilidade)
# Status       : fase validada e pronta para execução
# ...
#
# 🚀 Rodando benchmarks CKKS (unlabeled) para: Oficial – CheXchoNet
#
# ------------------------------------------------------------
# RESULTADO (médias por iteração):
# - Contexto CKKS    : 58.94 ms
# - Keygen           : 416.20 ms
# - Encrypt (clients): 55.73 ms
# - Aggregate        : 3.09 ms
# - Decrypt          : 2.18 ms
# - Payload/cipher   : 1.59 MB (média/iter)
# - Payload/total    : 1.59 MB (média/iter)
# - Erro médio abs   : 24.2381
# ------------------------------------------------------------
#
# ✅ Execução finalizada.
# ...
