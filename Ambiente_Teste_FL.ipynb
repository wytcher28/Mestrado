# %% [markdown]
# <a href="https://colab.research.google.com/github/wytcher28/Mestrado/blob/main/Ambiente_Teste_FL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
TRAIN_DIR = "/content/drive/MyDrive/Base de Dados/Treino"
X, y, df_all = load_dataset_csv(TRAIN_DIR, filename="dataset.csv", label_col="LABEL")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2403737273.py in <cell line: 0>()
#       1 TRAIN_DIR = "/content/drive/MyDrive/Base de Dados/Treino"
# ----> 2 X, y, df_all = load_dataset_csv(TRAIN_DIR, filename="dataset.csv", label_col="LABEL")
#
# /tmp/ipython-input-939679385.py in load_dataset_csv(folder, filename, label_col)
#       2     path = os.path.join(folder, filename)
#       3     if not os.path.exists(path):
# ----> 4         raise RuntimeError(
#       5             f"Não achei {filename} em {folder}. "
#       6             f"Crie {path} com uma coluna {label_col} e as features nas demais colunas."
#
# RuntimeError: Não achei dataset.csv em /content/drive/MyDrive/Base de Dados/Treino. Crie /content/drive/MyDrive/Base de Dados/Treino/dataset.csv com uma coluna LABEL e as features nas demais colunas.
